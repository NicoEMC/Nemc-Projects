# %% [markdown]
# # Trabajando con Imagenes

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ## Recorte Imagenes

# %%
### Visualizamos los archivos de la carpeta
ls
# Out:
#  El volumen de la unidad C es Acer
#  El n£mero de serie del volumen es: D20B-423D
#
#  Directorio de C:\Users\nmarq\Desktop\python\Fotos Python
#
# 14-09-2022  23:23    <DIR>          .
# 14-09-2022  23:23    <DIR>          ..
# 14-09-2022  22:28    <DIR>          .ipynb_checkpoints
# 14-09-2022  23:22           682.079 Ajuste_Instagram.ipynb
# 14-09-2022  22:19           327.658 foto_test.jpg
# 14-09-2022  22:21            70.740 insta.jpeg
# 31-07-2022  21:52             7.469 Untitled.ipynb
#                4 archivos      1.087.946 bytes
#                3 dirs  304.965.910.528 bytes libres

# %%
### Seleccionamos el nombre de la imagen
img = "insta.jpeg"

# %%
### Abrimos la imagen y vemos las dimensiones de ella
img = Image.open(img)
img.size
# Out:
# (540, 1170)

# %%
## Imagen original
plt.figure(figsize = (16,12))
imgplot = plt.imshow(img)
plt.show()

# %%
### Utilizamos crop para recortar la imagen, debemos ir probando para llegar a la imagen deseada
### crop(izquierda,arriba,derecha,abajo) <-- sectores que queremos cortar en pixeles
region = (0,140,540,740)
img_recortada = img.crop(region)

#img_recortada.show()
plt.figure(figsize = (16,12))
imgplot = plt.imshow(img_recortada)
plt.show()
print(img.size)
# Out:
# (540, 1170)
